# %%
import os
print(os.path.abspath(state_shapefile))
print(os.path.exists(state_shapefile))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 print(os.path.abspath(state_shapefile))
#       3 print(os.path.exists(state_shapefile))
#
# NameError: name 'state_shapefile' is not defined
